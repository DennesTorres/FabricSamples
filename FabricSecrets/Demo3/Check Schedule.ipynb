# %%
import sempy.fabric as fabric
from pyspark.sql.types import StructType, StructField, StringType, TimestampType

# Set the notebook ID you want to get the schedule for
notebook_id = "d0ea1670-d996-4101-a260-6a6a78f37fec"
workspaceId="b7374b1e-2ba8-475d-b8b8-a4b48f3ac96f"
jobType = "RunNotebook"
url=f"v1/workspaces/{workspaceId}/items/{notebook_id}/jobs/{jobType}/schedules"

# Create the Fabric REST client
client = fabric.FabricRestClient()

# Call the Get Item Schedule API
response = client.get(url)

print(response.json())
# Out:
# StatementMeta(, af6146a8-4688-4694-8177-218ad8d28357, 6, Finished, Available, Finished)
# {'value': [{'id': '59c38b30-462c-4596-b49b-4a22ed1ea9d5', 'enabled': True, 'createdDateTime': '2025-05-13T16:54:01.77', 'configuration': {'type': 'Cron', 'startDateTime': '2025-05-13T23:53:00', 'endDateTime': '2025-10-22T18:53:00', 'localTimeZoneId': 'Romance Standard Time', 'interval': 15}, 'owner': {'id': 'b5a85b13-fb3a-4227-8fad-7a1cdac762cb', 'type': 'User'}}]}
