# %%
from pyspark.sql.functions import explode, col,lit
import requests
import json
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 3, Finished, Available, Finished)

# %%
# Set dynamic partition overwrite mode
spark.conf.set("spark.sql.sources.partitionOverwriteMode", "dynamic")
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 4, Finished, Available, Finished)

# %%
# Function to get category IDs
def get_category_ids():
    response = requests.get("https://paralleldemo.azurewebsites.net/api/LoadCategories")
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception("Failed to load categories")
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 5, Finished, Available, Finished)

# %%
# Get list of category IDs
categories = get_category_ids()

# Initialize an empty list to hold DataFrames
dfCategories=spark.createDataFrame(categories)

DAG = {
    "activities": [
        {
            "name": f"category{row['categoryId']}", 
            "path": "Demo 2 -Load Orders", 
            "timeoutPerCellInSeconds": 4000,
            "args": {"categoryId": row["categoryId"] }
        }
        for row in dfCategories.rdd.collect()
                ],
        "concurrency": 0
    }
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 6, Finished, Available, Finished)

# %%
print(DAG)
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 7, Finished, Available, Finished)
# {'activities': [{'name': 'category7', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 7}}, {'name': 'category5', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 5}}, {'name': 'category6', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 6}}, {'name': 'category16', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 16}}, {'name': 'category25', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 25}}, {'name': 'category17', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 17}}, {'name': 'category18', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 18}}, {'name': 'category35', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 35}}, {'name': 'category20', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 20}}, {'name': 'category19', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 19}}, {'name': 'category8', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 8}}, {'name': 'category29', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 29}}, {'name': 'category26', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 26}}, {'name': 'category27', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 27}}, {'name': 'category24', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 24}}, {'name': 'category23', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 23}}, {'name': 'category10', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 10}}, {'name': 'category13', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 13}}, {'name': 'category30', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 30}}, {'name': 'category32', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 32}}, {'name': 'category33', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 33}}, {'name': 'category36', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 36}}, {'name': 'category12', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 12}}, {'name': 'category9', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 9}}, {'name': 'category11', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 11}}, {'name': 'category41', 'path': 'Demo 2 -Load Orders', 'timeoutPerCellInSeconds': 4000, 'args': {'categoryId': 41}}], 'concurrency': 0}

# %%
mssparkutils.notebook.runMultiple(DAG)
# Out:
# StatementMeta(, 01fcb6b1-a941-4cdf-9ac3-b992f529ab4f, 8, Finished, Available, Finished)
# {'category7': {'exitVal': '81', 'exception': None},
#  'category5': {'exitVal': '70', 'exception': None},
#  'category6': {'exitVal': '49', 'exception': None},
#  'category16': {'exitVal': '47', 'exception': None},
#  'category25': {'exitVal': '44', 'exception': None},
#  'category17': {'exitVal': '29', 'exception': None},
#  'category18': {'exitVal': '24', 'exception': None},
#  'category35': {'exitVal': '20', 'exception': None},
#  'category20': {'exitVal': '18', 'exception': None},
#  'category19': {'exitVal': '16', 'exception': None},
#  'category8': {'exitVal': '16', 'exception': None},
#  'category29': {'exitVal': '16', 'exception': None},
#  'category26': {'exitVal': '13', 'exception': None},
#  'category27': {'exitVal': '12', 'exception': None},
#  'category24': {'exitVal': '12', 'exception': None},
#  'category23': {'exitVal': '9', 'exception': None},
#  'category10': {'exitVal': '8', 'exception': None},
#  'category13': {'exitVal': '8', 'exception': None},
#  'category30': {'exitVal': '8', 'exception': None},
#  'category32': {'exitVal': '7', 'exception': None},
#  'category33': {'exitVal': '7', 'exception': None},
#  'category36': {'exitVal': '7', 'exception': None},
#  'category12': {'exitVal': '7', 'exception': None},
#  'category9': {'exitVal': '7', 'exception': None},
#  'category11': {'exitVal': '4', 'exception': None},
#  'category41': {'exitVal': '3', 'exception': None}}
