# %%
from pyspark.sql.functions import explode, col,lit
import requests
import json
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 3, Finished, Available, Finished)

# %%
# Set dynamic partition overwrite mode
spark.conf.set("spark.sql.sources.partitionOverwriteMode", "dynamic")
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 4, Finished, Available, Finished)

# %%
# Function to get category IDs
def get_category_ids():
    response = requests.get("https://paralleldemo.azurewebsites.net/api/LoadCategories")
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception("Failed to load categories")
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 5, Finished, Available, Finished)

# %%
# Get list of category IDs
categories = get_category_ids()

# Initialize an empty list to hold DataFrames
dfCategories=spark.createDataFrame(categories)

DAG = {
    "activities": [
        {
            "name": f"category{row['categoryId']}", 
            "path": "Demo 2 -Load Orders", 
            "timeoutPerCellInSeconds": 4000,
            "args": {"categoryId": row["categoryId"] }
        }
        for row in dfCategories.rdd.collect()
                ],
        "concurrency": 0
    }
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 6, Finished, Available, Finished)

# %%
result=mssparkutils.notebook.runMultiple(DAG)
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 7, Finished, Available, Finished)

# %%
print(result)
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 8, Finished, Available, Finished)
# {'category7': {'exitVal': '81', 'exception': None}, 'category5': {'exitVal': '70', 'exception': None}, 'category6': {'exitVal': '49', 'exception': None}, 'category16': {'exitVal': '47', 'exception': None}, 'category25': {'exitVal': '44', 'exception': None}, 'category17': {'exitVal': '29', 'exception': None}, 'category18': {'exitVal': '24', 'exception': None}, 'category35': {'exitVal': '20', 'exception': None}, 'category20': {'exitVal': '18', 'exception': None}, 'category19': {'exitVal': '16', 'exception': None}, 'category8': {'exitVal': '16', 'exception': None}, 'category29': {'exitVal': '16', 'exception': None}, 'category26': {'exitVal': '13', 'exception': None}, 'category27': {'exitVal': '12', 'exception': None}, 'category24': {'exitVal': '12', 'exception': None}, 'category23': {'exitVal': '9', 'exception': None}, 'category10': {'exitVal': '8', 'exception': None}, 'category13': {'exitVal': '8', 'exception': None}, 'category30': {'exitVal': '8', 'exception': None}, 'category32': {'exitVal': '7', 'exception': None}, 'category33': {'exitVal': '7', 'exception': None}, 'category36': {'exitVal': '7', 'exception': None}, 'category12': {'exitVal': '7', 'exception': None}, 'category9': {'exitVal': '7', 'exception': None}, 'category11': {'exitVal': '4', 'exception': None}, 'category41': {'exitVal': '3', 'exception': None}}

# %%
for key, value in result.items():
    print(f"Category: {key}, Exit Value: {value['exitVal']}")
# Out:
# StatementMeta(, 4b1f8e1f-8e7a-4cc1-8d59-20d05bdb3297, 9, Finished, Available, Finished)
# Category: category7, Exit Value: 81
# Category: category5, Exit Value: 70
# Category: category6, Exit Value: 49
# Category: category16, Exit Value: 47
# Category: category25, Exit Value: 44
# Category: category17, Exit Value: 29
# Category: category18, Exit Value: 24
# Category: category35, Exit Value: 20
# Category: category20, Exit Value: 18
# Category: category19, Exit Value: 16
# Category: category8, Exit Value: 16
# Category: category29, Exit Value: 16
# Category: category26, Exit Value: 13
# Category: category27, Exit Value: 12
# Category: category24, Exit Value: 12
# Category: category23, Exit Value: 9
# Category: category10, Exit Value: 8
# Category: category13, Exit Value: 8
# Category: category30, Exit Value: 8
# Category: category32, Exit Value: 7
# Category: category33, Exit Value: 7
# Category: category36, Exit Value: 7
# Category: category12, Exit Value: 7
# Category: category9, Exit Value: 7
# Category: category11, Exit Value: 4
# Category: category41, Exit Value: 3
