# %% [markdown]
# **Examine fact_sales files**

# %%
# %%sql
# update fact_sale set TotalIncludingTax=TotalIncludingTax * 2
# where SaleKey=45634459
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 2, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %% [markdown]
# **Check the fact_sales files. A single record updated in a PARQUET file (4th quarter) duplicates the entire file**

# %%
# %%sql
# update fact_sale set TotalIncludingTax=TotalIncludingTax * 2
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 3, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %% [markdown]
# **Check fact_sales files again**

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 5, Finished, Available)

# %%
# %%sql
# VACUUM demolake.fact_sale RETAIN 0 HOURS
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 6, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# insert into fact_sale (SaleKey,CityKey,CustomerKey,BillToCustomerKey,StockItemKey,
#                 InvoiceDateKey,DeliveryDateKey,SalespersonKey,WWIInvoiceID,Description,
#                 Package,Quantity, UnitPrice,TaxRate,TotalExcludingTax,TaxAmount,
#                 Profit,TotalIncludingTax,TotalDryItems,TotalChillerItems,LineageKey,Year,Quarter,Month)
#                 values (45257746,75266,190,1,191,'2000-10-29T00:00:00Z','2000-10-30T00:00:00Z',39,2430,'DBA joke mug - two types of DBAs(Black)','Each',
#                 9,13.00,15.000,117.00,17.55, 76.50,1076.40,9,0,11,2000,4,10)
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 7, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %% [markdown]
# **Check the fact_sales files again**

# %%
# %%sql
# VACUUM 'Tables/fact_sale' RETAIN 0 HOURS
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 8, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# select * from fact_sale
# where SaleKey=45257746
# Out:
# StatementMeta(, d284b748-f7a9-45bc-8801-87052449a420, 9, Finished, Available)
# <Spark SQL result set with 7 rows and 24 fields>

# %% [markdown]
# **VACUUM doesn't clean the files because they are not unlinked**

# %%
# %%sql
# OPTIMIZE fact_sale VORDER;

# %% [markdown]
# **Optimize join the files in a new one, but leave unlinked files behind**

# %%
# %%sql
# VACUUM 'Tables/fact_sale' RETAIN 0 HOURS

# %% [markdown]
# **VACUUM completes the work removing the unlinked files. A regular maintenance requires OPTIMIZE and VACUUM in this order**
