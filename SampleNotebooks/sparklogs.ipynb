# %%
df = spark.sql("SELECT * FROM demolake.orders LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 276e7857-1b88-4835-b982-b3bf331f09b6, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6b9b1af5-df8f-47b4-80eb-4dad01a1cd43)

# %%
import logging

logger = sc._jvm.org.apache.log4j.LogManager.getLogger("MyEmitter")
logger.info("my custom info message")
logger.warn("my custom warn message")
logger.error("my custom error message")
# Out:
# StatementMeta(, 276e7857-1b88-4835-b982-b3bf331f09b6, 4, Finished, Available, Finished)
