# %% [markdown]
# # This is a sample notebook used during the production of the video Fabric Monday 06 about delta table optimizations

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import pyarrow.dataset as pq
import os

def show_metadata(delta_file_path):
   
    # Print schema metadata
    print("\nSchema Properties:")
    print("--------------------")
    schema_properties = pq.dataset(delta_file_path).schema.metadata
    if schema_properties:
        for key, value in schema_properties.items():
            print(f"{key.decode('utf-8')}: {value.decode('utf-8')}")
    else:
        print("No schema properties found.")
   
    # Test the function with a path to your delta file#

full_tables = os.listdir('/lakehouse/default/Tables')

for table in full_tables:
     show_metadata('//lakehouse/default/Tables/' + table)

# %%
# %%sql
# update fact_sale set TotalIncludingTax=TotalIncludingTax * 2
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 2, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
spark.conf.set("spark.databricks.delta.retentionDurationCheck.enabled", "false")
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 4, Finished, Available)

# %%
# %%sql
# VACUUM 'Tables/fact_sale' RETAIN 0 HOURS
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 5, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# insert into fact_sale (SaleKey,CityKey,CustomerKey,BillToCustomerKey,StockItemKey,
#                 InvoiceDateKey,DeliveryDateKey,SalespersonKey,WWIInvoiceID,Description,
#                 Package,Quantity, UnitPrice,TaxRate,TotalExcludingTax,TaxAmount,
#                 Profit,TotalIncludingTax,TotalDryItems,TotalChillerItems,LineageKey,Year,Quarter,Month)
#                 values (45257746,75266,190,1,191,'2000-10-29T00:00:00Z','2000-10-30T00:00:00Z',39,2430,'DBA joke mug - two types of DBAs(Black)','Each',
#                 9,13.00,15.000,117.00,17.55, 76.50,1076.40,9,0,11,2000,4,10)
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 6, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# VACUUM 'Tables/fact_sale' RETAIN 0 HOURS
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 7, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# OPTIMIZE fact_sale VORDER;
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 8, Finished, Available)
# <Spark SQL result set with 1 rows and 2 fields>

# %%
# %%sql
# VACUUM 'Tables/fact_sale' RETAIN 0 HOURS
# Out:
# StatementMeta(, 0cc1c95d-5706-4800-ad6f-ad16c52cc5eb, 9, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>
