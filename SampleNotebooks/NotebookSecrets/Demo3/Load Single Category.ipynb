# %%
function_url="https://demoadventurefnc.azurewebsites.net/api/GetProducts?CategoryId=1"
cat=1
executionId="123456"

# %%
import requests

fetch_function = requests.get(function_url, timeout=300)    
result = fetch_function.text
mssparkutils.notebook.run("Save JSON Demo 3",arguments= { "contenttosave": fetch_function.text,"path": "products/", "filenameprefix": f"productcat{cat}", "ingestionid": executionId })

# %%
mssparkutils.notebook.exit(result)
