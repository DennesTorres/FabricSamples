# %%
clientId="7e41b580-0454-4bc3-9b2a-3ab668d0afd2"
clientSecret="~Ws8Q~jITAEjuU3HRjZxc.kUHtrdRTV6Gd~gJdbB"
warehouseName="mynewdw"
workspaceid="76e1cbdd-6d13-453e-ac86-7f9002636aeb"
# Out:
# StatementMeta(, 2df2ac88-2549-437f-82cd-4ad44d58caf4, 3, Finished, Available, Finished)

# %%
parameters= {
    "principalId": clientId,
    "principalSecret": clientSecret,
    "dwName": warehouseName,
    "wksId": workspaceid
}
# Out:
# StatementMeta(, 2df2ac88-2549-437f-82cd-4ad44d58caf4, 4, Finished, Available, Finished)

# %%
mssparkutils.notebook.run("Warehouse Create",500,parameters)
# Out:
# StatementMeta(, 2df2ac88-2549-437f-82cd-4ad44d58caf4, 5, Finished, Available, Finished)
# ''
